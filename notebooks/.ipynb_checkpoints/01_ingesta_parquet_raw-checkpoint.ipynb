# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, current_timestamp
from pyspark.sql.types import *
from datetime import datetime
import urllib.request
import json

print("Imports completados.")
# Out:
# Imports completados.

# %%
# Variables de conexion a PostgreSQL
POSTGRES_HOST = os.getenv("POSTGRES_HOST")
POSTGRES_PORT = os.getenv("POSTGRES_PORT")
POSTGRES_DB = os.getenv("POSTGRES_DB")
POSTGRES_USER = os.getenv("POSTGRES_USER")
POSTGRES_PASSWORD = os.getenv("POSTGRES_PASSWORD")
PG_SCHEMA_RAW = os.getenv("PG_SCHEMA_RAW")

# Variables de ingesta
SOURCE_BASE = os.getenv("SOURCE_BASE")
TAXI_ZONE_URL = os.getenv("TAXI_ZONE_URL")
START_YEAR = int(os.getenv("START_YEAR"))
END_YEAR = int(os.getenv("END_YEAR"))
SERVICES = os.getenv("SERVICES").split(",")
RUN_ID = os.getenv("RUN_ID")

# Archivo de checkpoint
CHECKPOINT_FILE = "/home/jovyan/work/checkpoint_ingesta.json"

# URL JDBC
JDBC_URL = f"jdbc:postgresql://{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DB}"

print("Variables de ambiente cargadas:")
print(f" - Schema RAW.")
print(f" - Periodo: {START_YEAR}-{END_YEAR}")
print(f" - Servicios: {SERVICES}")
print(f" - Checkpoint: {CHECKPOINT_FILE}")
# Out:
# Variables de ambiente cargadas:
#  - Schema RAW.
#  - Periodo: 2015-2025
#  - Servicios: ['yellow', 'green']
#  - Checkpoint: /home/jovyan/work/checkpoint_ingesta.json

# %%
# Descargar driver JDBC de PostgreSQL si no existe
jar_dir = "/home/jovyan/jars"
os.makedirs(jar_dir, exist_ok=True)

postgres_jar_url = "https://jdbc.postgresql.org/download/postgresql-42.7.1.jar"
postgres_jar_path = f"{jar_dir}/postgresql-42.7.1.jar"

if not os.path.exists(postgres_jar_path):
    print("Descargando PostgreSQL JDBC driver...")
    urllib.request.urlretrieve(postgres_jar_url, postgres_jar_path)
    print(f"Driver descargado: {postgres_jar_path}")
else:
    print(f"Driver ya existe: {postgres_jar_path}")
# Out:
# Descargando PostgreSQL JDBC driver...
# Driver descargado: /home/jovyan/jars/postgresql-42.7.1.jar

# %%
# Crear SparkSession con configuraciones optimizadas
spark = SparkSession.builder \
    .appName("NYC_TLC_to_Postgres") \
    .config("spark.jars", postgres_jar_path) \
    .config("spark.driver.memory", "3g") \
    .config("spark.executor.memory", "2g") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.sql.shuffle.partitions", "100") \
    .config("spark.driver.maxResultSize", "2g") \
    .config("spark.sql.session.timeZone", "UTC") \
    .getOrCreate()

print("SparkSession creada:")
print(f" - Spark Version: {spark.version}")
# Out:
# SparkSession creada:
#  - Spark Version: 3.5.0

# %%
# Funciones para manejar el sistema de checkpoint

def load_checkpoint():
    # Carga el estado del checkpoint desde archivo JSON.
    if os.path.exists(CHECKPOINT_FILE):
        try:
            with open(CHECKPOINT_FILE, 'r') as f:
                data = json.load(f)
                print(f"Checkpoint cargado: {len(data)} archivos registrados.")
                return data
        except Exception as e:
            print(f"Error leyendo checkpoint: {e}")
            return {}
    print("Checkpoint nuevo (sin archivos previos).")
    return {}

def save_checkpoint(checkpoint_data):
    # Guarda el estado del checkpoint.
    try:
        with open(CHECKPOINT_FILE, 'w') as f:
            json.dump(checkpoint_data, f, indent=2)
        return True
    except Exception as e:
        print(f"Error guardando checkpoint: {e}")
        return False

def mark_processed(checkpoint_data, service, year, month, status, rows=None, time_sec=None):
    # Marca un archivo como procesado en el checkpoint.
    key = f"{service}_{year}_{month:02d}"
    checkpoint_data[key] = {
        'status': status,
        'timestamp': datetime.now().isoformat(),
        'run_id': RUN_ID,
        'rows': rows,
        'time_seconds': time_sec
    }
    save_checkpoint(checkpoint_data)

def is_already_processed(checkpoint_data, service, year, month):
    # Verifica si un archivo ya fue procesado exitosamente.
    key = f"{service}_{year}_{month:02d}"
    if key in checkpoint_data:
        info = checkpoint_data[key]
        if info['status'] == 'SUCCESS':
            return True, info
    return False, None

print("Funciones de checkpoint definidas.")
# Out:
# Funciones de checkpoint definidas.

# %%
# Ingestar tabla de zonas de taxi (overwrite cada vez)
print("Ingiriendo taxi_zone_lookup...")

try:
    import pandas as pd
    
    print(f" - Descargando desde: {TAXI_ZONE_URL}")
    pdf_zones = pd.read_csv(TAXI_ZONE_URL)
    
    print(f" - Total filas: {len(pdf_zones)}")
    
    df_zones = spark.createDataFrame(pdf_zones)
    
    df_zones = df_zones.withColumn("ingested_at_utc", current_timestamp()) \
                       .withColumn("run_id", lit(RUN_ID))
    
    df_zones.write \
        .format("jdbc") \
        .option("url", JDBC_URL) \
        .option("dbtable", f"{PG_SCHEMA_RAW}.taxi_zone_lookup") \
        .option("user", POSTGRES_USER) \
        .option("password", POSTGRES_PASSWORD) \
        .option("driver", "org.postgresql.Driver") \
        .mode("overwrite") \
        .save()

    
    
    print("taxi_zone_lookup ingresado correctamente.\n")
    
except Exception as e:
    print(f"Error en taxi_zone_lookup: {str(e)}\n")
# Out:
# Ingiriendo taxi_zone_lookup...
#  - Descargando desde: https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
#  - Total filas: 265
# taxi_zone_lookup ingresado correctamente.

# %%
# Función para ingerir un mes específico con idempotencia

def ingest_month(service, year, month, checkpoint_data):
    """
    Ingiere un mes de Yellow o Green taxi con verificación de checkpoint.
    
    Args:
        service: 'yellow' o 'green'
        year: año
        month: mes
        checkpoint_data: diccionario con estado del checkpoint
    
    Returns:
        'SUCCESS', 'SKIPPED', 'NOT_FOUND', 'ERROR'
    """
    start_time = datetime.now()
    
    # Verificar si ya fue procesado
    already_done, info = is_already_processed(checkpoint_data, service, year, month)
    if already_done:
        print(f"  {service} {year}-{month:02d}: Ya procesado (SKIP) "
              f"[{info.get('rows', 'N/A')} filas, {info.get('time_seconds', 'N/A')}s]")
        return 'SKIPPED'
    
    filename = f"{service}_tripdata_{year}-{month:02d}.parquet"
    url = f"{SOURCE_BASE}/{filename}"
    local_path = f"/tmp/{filename}"
    table_name = f"{PG_SCHEMA_RAW}.{service}_taxi_trip"
    
    print(f"Procesando: {service} {year}-{month:02d}")
    
    try:
        # Descargar archivo
        print(f"  Descargando: {url}")
        urllib.request.urlretrieve(url, local_path)
        
        # Leer Parquet
        df = spark.read.parquet(local_path)
        
        # Estandarizar timestamps
        if service == 'yellow':
            if 'tpep_pickup_datetime' in df.columns:
                df = df.withColumn('tpep_pickup_datetime', 
                                 col('tpep_pickup_datetime').cast('timestamp'))
            if 'tpep_dropoff_datetime' in df.columns:
                df = df.withColumn('tpep_dropoff_datetime', 
                                 col('tpep_dropoff_datetime').cast('timestamp'))
        elif service == 'green':
            if 'lpep_pickup_datetime' in df.columns:
                df = df.withColumn('lpep_pickup_datetime', 
                                 col('lpep_pickup_datetime').cast('timestamp'))
            if 'lpep_dropoff_datetime' in df.columns:
                df = df.withColumn('lpep_dropoff_datetime', 
                                 col('lpep_dropoff_datetime').cast('timestamp'))
        
        # Agregar metadatos
        df = df.withColumn("run_id", lit(RUN_ID)) \
               .withColumn("source_year", lit(year)) \
               .withColumn("source_month", lit(month)) \
               .withColumn("ingested_at_utc", current_timestamp())
        
        count = df.count()
        print(f"  Filas leidas: {count:,}")
        
        # Escribir a Postgres
        df.write \
            .format("jdbc") \
            .option("url", JDBC_URL) \
            .option("dbtable", table_name) \
            .option("user", POSTGRES_USER) \
            .option("password", POSTGRES_PASSWORD) \
            .option("driver", "org.postgresql.Driver") \
            .mode("append") \
            .save()
        
        elapsed = (datetime.now() - start_time).total_seconds()
        
        print(f"  {service} {year}-{month:02d} ingresado correctamente ({elapsed:.2f}s)\n")
        
        mark_processed(checkpoint_data, service, year, month, 'SUCCESS', 
                      rows=count, time_sec=elapsed)
        
        # Limpiar archivo temporal
        if os.path.exists(local_path):
            os.remove(local_path)
        
        return 'SUCCESS'
            
    except urllib.error.HTTPError as e:
        elapsed = (datetime.now() - start_time).total_seconds()
        
        if e.code == 404 or e.code == 403:
            print(f"  Archivo no encontrado ({e.code}), saltando...\n")
            mark_processed(checkpoint_data, service, year, month, 'NOT_FOUND', 
                          time_sec=elapsed)
            status = 'NOT_FOUND'
        else:
            print(f"  Error HTTP {e.code}: {str(e)}\n")
            mark_processed(checkpoint_data, service, year, month, 'ERROR', 
                          time_sec=elapsed)
            status = 'ERROR'
        
        if os.path.exists(local_path):
            os.remove(local_path)
        
        return status
        
    except Exception as e:
        elapsed = (datetime.now() - start_time).total_seconds()
        
        print(f"  Error: {str(e)}\n")
        mark_processed(checkpoint_data, service, year, month, 'ERROR', 
                      time_sec=elapsed)
        
        if os.path.exists(local_path):
            os.remove(local_path)
        
        return 'ERROR'

print("Funcion ingest_month definida.")
# Out:
# Funcion ingest_month definida.

# %%
# Ejecutar ingesta masiva con idempotencia

print("=" * 80)
print("INICIANDO INGESTA MASIVA NYC TLC -> POSTGRES")
print("=" * 80)
print(f"Inicio: {datetime.now()}")
print(f"Servicios: {SERVICES}")
print(f"Rango: {START_YEAR}-{END_YEAR}")
print(f"Run ID: {RUN_ID}")
print("=" * 80)
print()

# Cargar checkpoint
checkpoint_data = load_checkpoint()
print()

# Contadores
stats = {
    'SUCCESS': 0,
    'SKIPPED': 0,
    'NOT_FOUND': 0,
    'ERROR': 0
}

ingestion_start = datetime.now()

# Loop por servicio, año y mes
for service in SERVICES:
    print(f"\n{'='*80}")
    print(f"Servicio: {service.upper()}")
    print(f"{'='*80}\n")
    
    for year in range(START_YEAR, END_YEAR + 1):
        # Para 2025: solo hasta septiembre
        if year == 2025:
            max_month = 9
        else:
            max_month = 12
        
        for month in range(1, max_month + 1):
            result = ingest_month(service, year, month, checkpoint_data)
            stats[result] = stats.get(result, 0) + 1

total_duration = (datetime.now() - ingestion_start).total_seconds()

print("\n" + "=" * 80)
print("RESUMEN FINAL DE INGESTA")
print("=" * 80)
print(f"Exitosos:       {stats['SUCCESS']}")
print(f"Omitidos:       {stats['SKIPPED']}")
print(f"No encontrados: {stats['NOT_FOUND']}")
print(f"Fallidos:       {stats['ERROR']}")
print(f"Rango:          {START_YEAR}-{END_YEAR}")
print(f"Servicios:      {', '.join(SERVICES)}")
print(f"Run ID:         {RUN_ID}")
print(f"Checkpoint:     {CHECKPOINT_FILE}")
print(f"Duracion total: {total_duration:.2f}s ({total_duration/60:.2f} min)")
print(f"Fin: {datetime.now()}")
print("=" * 80)
# Out:
# ================================================================================
# INICIANDO INGESTA MASIVA NYC TLC -> POSTGRES
# ================================================================================
# Inicio: 2025-11-11 13:19:00.976454
# Servicios: ['yellow', 'green']
# Rango: 2015-2025
# Run ID: run_001
# ================================================================================
#
# Checkpoint cargado: 258 archivos registrados.
#
#
# ================================================================================
# Servicio: YELLOW
# ================================================================================
#
#   yellow 2015-01: Ya procesado (SKIP) [12741035 filas, 494.63848s]
#   yellow 2015-02: Ya procesado (SKIP) [12442394 filas, 339.948858s]
#   yellow 2015-03: Ya procesado (SKIP) [13342951 filas, 364.81764s]
#   yellow 2015-04: Ya procesado (SKIP) [13063758 filas, 350.321475s]
#   yellow 2015-05: Ya procesado (SKIP) [13157677 filas, 359.700977s]
#   yellow 2015-06: Ya procesado (SKIP) [12324936 filas, 334.870962s]
#   yellow 2015-07: Ya procesado (SKIP) [11559666 filas, 312.419438s]
#   yellow 2015-08: Ya procesado (SKIP) [11123123 filas, 308.906263s]
#   yellow 2015-09: Ya procesado (SKIP) [11218122 filas, 303.17454s]
#   yellow 2015-10: Ya procesado (SKIP) [12307333 filas, 336.394519s]
#   yellow 2015-11: Ya procesado (SKIP) [11305240 filas, 307.264311s]
#   yellow 2015-12: Ya procesado (SKIP) [11452996 filas, 320.240544s]
#   yellow 2016-01: Ya procesado (SKIP) [10905067 filas, 305.041791s]
#   yellow 2016-02: Ya procesado (SKIP) [11375412 filas, 307.428178s]
#   yellow 2016-03: Ya procesado (SKIP) [12203824 filas, 337.217295s]
#   yellow 2016-04: Ya procesado (SKIP) [11927996 filas, 324.705884s]
#   yellow 2016-05: Ya procesado (SKIP) [11832049 filas, 322.752759s]
#   yellow 2016-06: Ya procesado (SKIP) [11131645 filas, 308.396197s]
#   yellow 2016-07: Ya procesado (SKIP) [10294080 filas, 286.000813s]
#   yellow 2016-08: Ya procesado (SKIP) [9942263 filas, 277.21119s]
#   yellow 2016-09: Ya procesado (SKIP) [10116018 filas, 277.446367s]
#   yellow 2016-10: Ya procesado (SKIP) [10854626 filas, 301.640565s]
#   yellow 2016-11: Ya procesado (SKIP) [10102128 filas, 271.422439s]
#   yellow 2016-12: Ya procesado (SKIP) [10446697 filas, 286.972424s]
#   yellow 2017-01: Ya procesado (SKIP) [9710820 filas, 259.085792s]
#   yellow 2017-02: Ya procesado (SKIP) [9169775 filas, 254.064356s]
#   yellow 2017-03: Ya procesado (SKIP) [10295441 filas, 289.9721s]
#   yellow 2017-04: Ya procesado (SKIP) [10047135 filas, 276.769718s]
#   yellow 2017-05: Ya procesado (SKIP) [10102127 filas, 274.986058s]
#   yellow 2017-06: Ya procesado (SKIP) [9656993 filas, 267.775568s]
#   yellow 2017-07: Ya procesado (SKIP) [8588486 filas, 231.464181s]
#   yellow 2017-08: Ya procesado (SKIP) [8422153 filas, 237.50273s]
#   yellow 2017-09: Ya procesado (SKIP) [8945421 filas, 249.093818s]
#   yellow 2017-10: Ya procesado (SKIP) [9768672 filas, 271.089645s]
#   yellow 2017-11: Ya procesado (SKIP) [9284803 filas, 256.588074s]
#   yellow 2017-12: Ya procesado (SKIP) [9508501 filas, 264.084985s]
#   yellow 2018-01: Ya procesado (SKIP) [8760687 filas, 244.790465s]
#   yellow 2018-02: Ya procesado (SKIP) [8492819 filas, 236.549421s]
#   yellow 2018-03: Ya procesado (SKIP) [9431289 filas, 264.377394s]
#   yellow 2018-04: Ya procesado (SKIP) [9306216 filas, 265.757641s]
#   yellow 2018-05: Ya procesado (SKIP) [9224788 filas, 254.555996s]
#   yellow 2018-06: Ya procesado (SKIP) [8714667 filas, 243.513145s]
#   yellow 2018-07: Ya procesado (SKIP) [7851143 filas, 222.254624s]
#   yellow 2018-08: Ya procesado (SKIP) [7855040 filas, 220.911967s]
#   yellow 2018-09: Ya procesado (SKIP) [8049094 filas, 234.039322s]
#   yellow 2018-10: Ya procesado (SKIP) [8834520 filas, 257.86487s]
#   yellow 2018-11: Ya procesado (SKIP) [8155449 filas, 233.517899s]
#   yellow 2018-12: Ya procesado (SKIP) [8195675 filas, 435.741835s]
#   yellow 2019-01: Ya procesado (SKIP) [7696617 filas, 214.594149s]
#   yellow 2019-02: Ya procesado (SKIP) [7049370 filas, 202.910567s]
#   yellow 2019-03: Ya procesado (SKIP) [7866620 filas, 226.693769s]
#   yellow 2019-04: Ya procesado (SKIP) [7475949 filas, 210.512175s]
#   yellow 2019-05: Ya procesado (SKIP) [7598445 filas, 219.577626s]
#   yellow 2019-06: Ya procesado (SKIP) [6971560 filas, 203.530163s]
#   yellow 2019-07: Ya procesado (SKIP) [6310419 filas, 180.789407s]
#   yellow 2019-08: Ya procesado (SKIP) [6073357 filas, 180.614615s]
#   yellow 2019-09: Ya procesado (SKIP) [6567788 filas, 188.933994s]
#   yellow 2019-10: Ya procesado (SKIP) [7213891 filas, 203.924768s]
#   yellow 2019-11: Ya procesado (SKIP) [6878111 filas, 199.10042s]
#   yellow 2019-12: Ya procesado (SKIP) [6896317 filas, 201.065839s]
#   yellow 2020-01: Ya procesado (SKIP) [6405008 filas, 189.646341s]
#   yellow 2020-02: Ya procesado (SKIP) [6299367 filas, 181.333186s]
#   yellow 2020-03: Ya procesado (SKIP) [3007687 filas, 85.797417s]
#   yellow 2020-04: Ya procesado (SKIP) [238073 filas, 7.828778s]
#   yellow 2020-05: Ya procesado (SKIP) [348415 filas, 11.180252s]
#   yellow 2020-06: Ya procesado (SKIP) [549797 filas, 17.460543s]
#   yellow 2020-07: Ya procesado (SKIP) [800412 filas, 24.198885s]
#   yellow 2020-08: Ya procesado (SKIP) [1007286 filas, 29.340626s]
#   yellow 2020-09: Ya procesado (SKIP) [1341017 filas, 40.27107s]
#   yellow 2020-10: Ya procesado (SKIP) [1681132 filas, 52.009447s]
#   yellow 2020-11: Ya procesado (SKIP) [1509000 filas, 82.233442s]
#   yellow 2020-12: Ya procesado (SKIP) [1461898 filas, 42.534606s]
#   yellow 2021-01: Ya procesado (SKIP) [1369769 filas, 40.668873s]
#   yellow 2021-02: Ya procesado (SKIP) [1371709 filas, 39.27768s]
#   yellow 2021-03: Ya procesado (SKIP) [1925152 filas, 54.841991s]
#   yellow 2021-04: Ya procesado (SKIP) [2171187 filas, 62.421372s]
#   yellow 2021-05: Ya procesado (SKIP) [2507109 filas, 72.05205s]
#   yellow 2021-06: Ya procesado (SKIP) [2834264 filas, 81.455088s]
#   yellow 2021-07: Ya procesado (SKIP) [2821746 filas, 84.90822s]
#   yellow 2021-08: Ya procesado (SKIP) [2788757 filas, 82.016343s]
#   yellow 2021-09: Ya procesado (SKIP) [2963793 filas, 84.607827s]
#   yellow 2021-10: Ya procesado (SKIP) [3463504 filas, 98.807855s]
#   yellow 2021-11: Ya procesado (SKIP) [3472949 filas, 98.752901s]
#   yellow 2021-12: Ya procesado (SKIP) [3214369 filas, 91.989873s]
#   yellow 2022-01: Ya procesado (SKIP) [2463931 filas, 96.449012s]
#   yellow 2022-02: Ya procesado (SKIP) [2979431 filas, 81.911236s]
#   yellow 2022-03: Ya procesado (SKIP) [3627882 filas, 103.163437s]
#   yellow 2022-04: Ya procesado (SKIP) [3599920 filas, 102.744957s]
#   yellow 2022-05: Ya procesado (SKIP) [3588295 filas, 100.21741s]
#   yellow 2022-06: Ya procesado (SKIP) [3558124 filas, 100.635326s]
#   yellow 2022-07: Ya procesado (SKIP) [3174394 filas, 93.742165s]
#   yellow 2022-08: Ya procesado (SKIP) [3152677 filas, 88.261727s]
#   yellow 2022-09: Ya procesado (SKIP) [3183767 filas, 90.022268s]
#   yellow 2022-10: Ya procesado (SKIP) [3675411 filas, 105.126631s]
#   yellow 2022-11: Ya procesado (SKIP) [3252717 filas, 119.488459s]
#   yellow 2022-12: Ya procesado (SKIP) [3399549 filas, 98.114485s]
#   yellow 2023-01: Ya procesado (SKIP) [3066766 filas, 88.45043s]
#   yellow 2023-02: Ya procesado (SKIP) [2913955 filas, 83.560631s]
#   yellow 2023-03: Ya procesado (SKIP) [3403766 filas, 96.14037s]
#   yellow 2023-04: Ya procesado (SKIP) [3288250 filas, 92.831729s]
#   yellow 2023-05: Ya procesado (SKIP) [3513649 filas, 96.820448s]
#   yellow 2023-06: Ya procesado (SKIP) [3307234 filas, 94.96058s]
#   yellow 2023-07: Ya procesado (SKIP) [2907108 filas, 83.512805s]
#   yellow 2023-08: Ya procesado (SKIP) [2824209 filas, 55.182712s]
#   yellow 2023-09: Ya procesado (SKIP) [2846722 filas, 55.557622s]
#   yellow 2023-10: Ya procesado (SKIP) [3522285 filas, 67.628369s]
#   yellow 2023-11: Ya procesado (SKIP) [3339715 filas, 64.221568s]
#   yellow 2023-12: Ya procesado (SKIP) [3376567 filas, 64.161996s]
#   yellow 2024-01: Ya procesado (SKIP) [2964624 filas, 59.69819s]
#   yellow 2024-02: Ya procesado (SKIP) [3007526 filas, 61.004842s]
#   yellow 2024-03: Ya procesado (SKIP) [3582628 filas, 68.688719s]
#   yellow 2024-04: Ya procesado (SKIP) [3514289 filas, 67.952533s]
#   yellow 2024-05: Ya procesado (SKIP) [3723833 filas, 72.303115s]
#   yellow 2024-06: Ya procesado (SKIP) [3539193 filas, 69.577934s]
#   yellow 2024-07: Ya procesado (SKIP) [3076903 filas, 77.906001s]
#   yellow 2024-08: Ya procesado (SKIP) [2979183 filas, 60.218602s]
#   yellow 2024-09: Ya procesado (SKIP) [3633030 filas, 72.540259s]
#   yellow 2024-10: Ya procesado (SKIP) [3833771 filas, 94.644317s]
#   yellow 2024-11: Ya procesado (SKIP) [3646369 filas, 84.032981s]
#   yellow 2024-12: Ya procesado (SKIP) [3668371 filas, 72.696458s]
#   yellow 2025-01: Ya procesado (SKIP) [3475226 filas, 80.897711s]
#   yellow 2025-02: Ya procesado (SKIP) [3577543 filas, 81.120227s]
#   yellow 2025-03: Ya procesado (SKIP) [4145257 filas, 136.908123s]
#   yellow 2025-04: Ya procesado (SKIP) [3970553 filas, 93.941106s]
#   yellow 2025-05: Ya procesado (SKIP) [4591845 filas, 112.143901s]
#   yellow 2025-06: Ya procesado (SKIP) [4322960 filas, 106.900414s]
#   yellow 2025-07: Ya procesado (SKIP) [3898963 filas, 96.770331s]
#   yellow 2025-08: Ya procesado (SKIP) [3574091 filas, 109.281766s]
#   yellow 2025-09: Ya procesado (SKIP) [4251015 filas, 173.873075s]
#
# ================================================================================
# Servicio: GREEN
# ================================================================================
#
#   green 2015-01: Ya procesado (SKIP) [1508493 filas, 45.402486s]
#   green 2015-02: Ya procesado (SKIP) [1574830 filas, 47.060252s]
#   green 2015-03: Ya procesado (SKIP) [1722574 filas, 51.600149s]
#   green 2015-04: Ya procesado (SKIP) [1664394 filas, 50.882582s]
#   green 2015-05: Ya procesado (SKIP) [1786848 filas, 53.026007s]
#   green 2015-06: Ya procesado (SKIP) [1638868 filas, 54.647252s]
#   green 2015-07: Ya procesado (SKIP) [1541671 filas, 48.479503s]
#   green 2015-08: Ya procesado (SKIP) [1532343 filas, 49.18342s]
#   green 2015-09: Ya procesado (SKIP) [1494927 filas, 46.274572s]
#   green 2015-10: Ya procesado (SKIP) [1630536 filas, 52.876946s]
#   green 2015-11: Ya procesado (SKIP) [1529984 filas, 48.926557s]
#   green 2015-12: Ya procesado (SKIP) [1608297 filas, 54.280331s]
#   green 2016-01: Ya procesado (SKIP) [1445292 filas, 48.692978s]
#   green 2016-02: Ya procesado (SKIP) [1510722 filas, 44.499379s]
#   green 2016-03: Ya procesado (SKIP) [1576393 filas, 47.470374s]
#   green 2016-04: Ya procesado (SKIP) [1543926 filas, 45.505105s]
#   green 2016-05: Ya procesado (SKIP) [1536979 filas, 44.524303s]
#   green 2016-06: Ya procesado (SKIP) [1404727 filas, 43.206054s]
#   green 2016-07: Ya procesado (SKIP) [1332510 filas, 38.710207s]
#   green 2016-08: Ya procesado (SKIP) [1247675 filas, 37.570801s]
#   green 2016-09: Ya procesado (SKIP) [1162373 filas, 33.544278s]
#   green 2016-10: Ya procesado (SKIP) [1252572 filas, 36.183984s]
#   green 2016-11: Ya procesado (SKIP) [1148214 filas, 33.941095s]
#   green 2016-12: Ya procesado (SKIP) [1224158 filas, 38.629844s]
#   green 2017-01: Ya procesado (SKIP) [1069565 filas, 33.802207s]
#   green 2017-02: Ya procesado (SKIP) [1022313 filas, 30.411047s]
#   green 2017-03: Ya procesado (SKIP) [1157827 filas, 34.028088s]
#   green 2017-04: Ya procesado (SKIP) [1080844 filas, 32.562417s]
#   green 2017-05: Ya procesado (SKIP) [1059463 filas, 31.315665s]
#   green 2017-06: Ya procesado (SKIP) [976467 filas, 29.061747s]
#   green 2017-07: Ya procesado (SKIP) [914783 filas, 27.497919s]
#   green 2017-08: Ya procesado (SKIP) [867407 filas, 26.169515s]
#   green 2017-09: Ya procesado (SKIP) [882464 filas, 27.301783s]
#   green 2017-10: Ya procesado (SKIP) [925737 filas, 28.558403s]
#   green 2017-11: Ya procesado (SKIP) [874173 filas, 26.523283s]
#   green 2017-12: Ya procesado (SKIP) [906016 filas, 26.378419s]
#   green 2018-01: Ya procesado (SKIP) [792744 filas, 23.560944s]
#   green 2018-02: Ya procesado (SKIP) [769197 filas, 23.276896s]
#   green 2018-03: Ya procesado (SKIP) [836246 filas, 30.429282s]
#   green 2018-04: Ya procesado (SKIP) [799383 filas, 23.711316s]
#   green 2018-05: Ya procesado (SKIP) [796552 filas, 23.862532s]
#   green 2018-06: Ya procesado (SKIP) [738546 filas, 28.003669s]
#   green 2018-07: Ya procesado (SKIP) [684374 filas, 25.68477s]
#   green 2018-08: Ya procesado (SKIP) [675815 filas, 23.304492s]
#   green 2018-09: Ya procesado (SKIP) [682032 filas, 25.330788s]
#   green 2018-10: Ya procesado (SKIP) [731888 filas, 27.298064s]
#   green 2018-11: Ya procesado (SKIP) [673287 filas, 23.167404s]
#   green 2018-12: Ya procesado (SKIP) [719654 filas, 25.161597s]
#   green 2019-01: Ya procesado (SKIP) [672105 filas, 20.274753s]
#   green 2019-02: Ya procesado (SKIP) [615594 filas, 22.305702s]
#   green 2019-03: Ya procesado (SKIP) [643063 filas, 20.282325s]
#   green 2019-04: Ya procesado (SKIP) [567852 filas, 19.806038s]
#   green 2019-05: Ya procesado (SKIP) [545452 filas, 20.416638s]
#   green 2019-06: Ya procesado (SKIP) [506238 filas, 15.915376s]
#   green 2019-07: Ya procesado (SKIP) [470743 filas, 14.902893s]
#   green 2019-08: Ya procesado (SKIP) [449695 filas, 17.898292s]
#   green 2019-09: Ya procesado (SKIP) [449063 filas, 13.873373s]
#   green 2019-10: Ya procesado (SKIP) [476386 filas, 17.916616s]
#   green 2019-11: Ya procesado (SKIP) [449500 filas, 13.508728s]
#   green 2019-12: Ya procesado (SKIP) [455294 filas, 14.011296s]
#   green 2020-01: Ya procesado (SKIP) [447770 filas, 16.339419s]
#   green 2020-02: Ya procesado (SKIP) [398632 filas, 13.209702s]
#   green 2020-03: Ya procesado (SKIP) [223496 filas, 8.353502s]
#   green 2020-04: Ya procesado (SKIP) [35644 filas, 2.105647s]
#   green 2020-05: Ya procesado (SKIP) [57361 filas, 2.721986s]
#   green 2020-06: Ya procesado (SKIP) [63110 filas, 2.828969s]
#   green 2020-07: Ya procesado (SKIP) [72258 filas, 3.094416s]
#   green 2020-08: Ya procesado (SKIP) [81063 filas, 3.320925s]
#   green 2020-09: Ya procesado (SKIP) [87987 filas, 3.530858s]
#   green 2020-10: Ya procesado (SKIP) [95120 filas, 3.688069s]
#   green 2020-11: Ya procesado (SKIP) [88605 filas, 3.510634s]
#   green 2020-12: Ya procesado (SKIP) [83130 filas, 3.428301s]
#   green 2021-01: Ya procesado (SKIP) [76518 filas, 3.281937s]
#   green 2021-02: Ya procesado (SKIP) [64572 filas, 2.876635s]
#   green 2021-03: Ya procesado (SKIP) [83827 filas, 3.47045s]
#   green 2021-04: Ya procesado (SKIP) [86941 filas, 3.611391s]
#   green 2021-05: Ya procesado (SKIP) [88180 filas, 3.482812s]
#   green 2021-06: Ya procesado (SKIP) [86737 filas, 3.555414s]
#   green 2021-07: Ya procesado (SKIP) [83691 filas, 3.439057s]
#   green 2021-08: Ya procesado (SKIP) [83499 filas, 3.313352s]
#   green 2021-09: Ya procesado (SKIP) [95709 filas, 4.098014s]
#   green 2021-10: Ya procesado (SKIP) [110891 filas, 4.310961s]
#   green 2021-11: Ya procesado (SKIP) [108229 filas, 4.215062s]
#   green 2021-12: Ya procesado (SKIP) [99961 filas, 4.07755s]
#   green 2022-01: Ya procesado (SKIP) [62495 filas, 3.012472s]
#   green 2022-02: Ya procesado (SKIP) [69399 filas, 3.216708s]
#   green 2022-03: Ya procesado (SKIP) [78537 filas, 3.39426s]
#   green 2022-04: Ya procesado (SKIP) [76136 filas, 3.270265s]
#   green 2022-05: Ya procesado (SKIP) [76891 filas, 3.502676s]
#   green 2022-06: Ya procesado (SKIP) [73718 filas, 3.268167s]
#   green 2022-07: Ya procesado (SKIP) [64192 filas, 3.018549s]
#   green 2022-08: Ya procesado (SKIP) [65929 filas, 3.064988s]
#   green 2022-09: Ya procesado (SKIP) [69031 filas, 3.246403s]
#   green 2022-10: Ya procesado (SKIP) [69322 filas, 4.539412s]
#   green 2022-11: Ya procesado (SKIP) [62313 filas, 3.039938s]
#   green 2022-12: Ya procesado (SKIP) [72439 filas, 3.420378s]
#   green 2023-01: Ya procesado (SKIP) [68211 filas, 3.092325s]
#   green 2023-02: Ya procesado (SKIP) [64809 filas, 3.262376s]
#   green 2023-03: Ya procesado (SKIP) [72044 filas, 4.178839s]
#   green 2023-04: Ya procesado (SKIP) [65392 filas, 3.203444s]
#   green 2023-05: Ya procesado (SKIP) [69174 filas, 3.110308s]
#   green 2023-06: Ya procesado (SKIP) [65550 filas, 3.004732s]
#   green 2023-07: Ya procesado (SKIP) [61343 filas, 2.935573s]
#   green 2023-08: Ya procesado (SKIP) [60649 filas, 3.076103s]
#   green 2023-09: Ya procesado (SKIP) [65471 filas, 3.099242s]
#   green 2023-10: Ya procesado (SKIP) [66177 filas, 3.328108s]
#   green 2023-11: Ya procesado (SKIP) [64025 filas, 3.219235s]
#   green 2023-12: Ya procesado (SKIP) [64215 filas, 3.158048s]
#   green 2024-01: Ya procesado (SKIP) [56551 filas, 6.740166s]
#   green 2024-02: Ya procesado (SKIP) [53577 filas, 2.718972s]
#   green 2024-03: Ya procesado (SKIP) [57457 filas, 2.87129s]
#   green 2024-04: Ya procesado (SKIP) [56471 filas, 2.824683s]
#   green 2024-05: Ya procesado (SKIP) [61003 filas, 2.940055s]
#   green 2024-06: Ya procesado (SKIP) [54748 filas, 2.752664s]
#   green 2024-07: Ya procesado (SKIP) [51837 filas, 2.643793s]
#   green 2024-08: Ya procesado (SKIP) [51771 filas, 2.821737s]
#   green 2024-09: Ya procesado (SKIP) [54440 filas, 3.068621s]
#   green 2024-10: Ya procesado (SKIP) [56147 filas, 3.039402s]
#   green 2024-11: Ya procesado (SKIP) [52222 filas, 2.834356s]
#   green 2024-12: Ya procesado (SKIP) [53994 filas, 3.031095s]
#   green 2025-01: Ya procesado (SKIP) [48326 filas, 6.96755s]
#   green 2025-02: Ya procesado (SKIP) [46621 filas, 6.868313s]
#   green 2025-03: Ya procesado (SKIP) [51539 filas, 7.066291s]
#   green 2025-04: Ya procesado (SKIP) [52132 filas, 7.878568s]
#   green 2025-05: Ya procesado (SKIP) [55399 filas, 8.107572s]
#   green 2025-06: Ya procesado (SKIP) [49390 filas, 7.748721s]
#   green 2025-07: Ya procesado (SKIP) [48205 filas, 6.590976s]
#   green 2025-08: Ya procesado (SKIP) [46306 filas, 7.267445s]
#   green 2025-09: Ya procesado (SKIP) [48893 filas, 7.819072s]
#
# ================================================================================
# RESUMEN FINAL DE INGESTA
# ================================================================================
# Exitosos:       0
# Omitidos:       258
# No encontrados: 0
# Fallidos:       0
# Rango:          2015-2025
# Servicios:      yellow, green
# Run ID:         run_001
# Checkpoint:     /home/jovyan/work/checkpoint_ingesta.json
# Duracion total: 0.00s (0.00 min)
# Fin: 2025-11-11 13:19:00.984427
# ================================================================================
